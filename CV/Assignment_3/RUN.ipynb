# %% [markdown]
# ### Q1: Datasets

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

import torch
from torchvision import datasets, transforms
from torch import nn, optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
from Utils import *
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# #### Part 1

# %%
trainset1 = DataAugment('./dataset/',type = 1,train= True)
trainloader1 = DataLoader(trainset1, batch_size = 1, shuffle = True)

idx, data = next(enumerate(trainloader1))
plt.imshow(data['y_mask'][0][0],cmap = plt.cm.gray)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Part 2

# %%
trainset2 = DataAugment('./dataset/',train= True,type = 2)
trainloader2 = DataLoader(trainset2, batch_size = 1, shuffle = True)

idx, data = next(enumerate(trainloader2))
plt.subplot(1,2,1)
plt.imshow(data['y_mask'][0][0],cmap = plt.cm.gray)
plt.axis('off')
plt.subplot(1,2,2)
img = data['y_mask'][0][0].numpy().astype(np.uint8); x= 28*data['y_cx'][0]; y = 28*data['y_cy'][0]; r = 28*data['y_r'][0]
cv2.circle(img, (int(x),int(y)),int(r),(1,0,0),thickness = 2)
plt.imshow(img,cmap = plt.cm.gray)

plt.show()

print(data['y_r'],data['y_cx'],data['y_cy'],y)
# Out:
# tensor([0.3529]) tensor([0.4832]) tensor([0.5796]) tensor(16.2289)

# %%
trainset3 = DataAugment3('./dataset/',train= True)
trainloader3 = DataLoader(trainset3, batch_size = 1, shuffle = True)


idx,data = next(enumerate(trainloader3))
plt.subplot(1,2,1)
plt.imshow(data['x'][0][0],cmap = plt.cm.gray); plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(data['seg_mask'][0],cmap = plt.cm.gray); plt.axis('off')
plt.show()

# %%
## Import dataset, apply augmentations 1, 2, 3
## 1 - foreground extraction img -> img
## 2 - circulization on extracted forground img-> class,r ,x,y
## 3 - concatenation of images
